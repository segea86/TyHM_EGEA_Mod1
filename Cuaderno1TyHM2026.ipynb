# %% [markdown]
# #Este es mi primer cuaderno
# Aquí voy a mezclar código markdown con operaciones matemáticas.
# * sumar
# * restar
# * multiplicar
# * dividir

# %%
a = 3
b = 5
a + b
# Out:
# [1] 8

# %% [markdown]
# Entramos a Google Collab, pusimos en archivo nuevo libro en drive Ahí se abrió otra ventana en el libro de drive, luego en editar, configuración de cuaderno y seleccionamos lenguaje R y el tipo de CPU que queramos utilizar, lo demás no se toca. Listo. Para escribir texto seleccionamos en +texto O para escribir código hay que seleccionar +código. En caso de confusión (haber escrito texto en un bloque de código o al revés) no se puede convertir el bloque de código a texto y viceversa, hay que copiar y borrar el otro bloque.
